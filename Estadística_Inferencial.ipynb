# %% [markdown]
# Fuente de los datos de: https://www.kaggle.com/datasets/merishnasuwal/breast-cancer-prediction-dataset/
#
# Archivo alojado en la carpeta raiz:

# %%
import pandas as pd
import numpy as np
#Importar el dataset alojado en google drive

from google.colab import drive
drive.mount('/content/drive')

# !wget 'https://drive.google.com/uc?export=download&id=1VNp6srOF9wBND98nUVReoBYm6WQ-VPN0' -O Datos_semana6_Cancer.csv

df = pd.read_csv('Datos_semana6_Cancer.csv')

df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# --2023-12-07 14:47:29--  https://drive.google.com/uc?export=download&id=1VNp6srOF9wBND98nUVReoBYm6WQ-VPN0
# Resolving drive.google.com (drive.google.com)... 172.217.204.139, 172.217.204.102, 172.217.204.113, ...
# Connecting to drive.google.com (drive.google.com)|172.217.204.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0g-7g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/tf9fli83987pae36592kbdrmpqlmenrr/1701960450000/03559725261241112129/*/1VNp6srOF9wBND98nUVReoBYm6WQ-VPN0?e=download&uuid=13a86ec4-bd98-44c8-8938-e4b775ca01f4 [following]
# Warning: wildcards not supported in HTTP.
# --2023-12-07 14:47:30--  https://doc-0g-7g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/tf9fli83987pae36592kbdrmpqlmenrr/1701960450000/03559725261241112129/*/1VNp6srOF9wBND98nUVReoBYm6WQ-VPN0?e=download&uuid=13a86ec4-bd98-44c8-8938-e4b775ca01f4
# Resolving doc-0g-7g-docs.googleusercontent.com (doc-0g-7g-docs.googleusercontent.com)... 173.194.215.132, 2607:f8b0:400c:c0c::84
# Connecting to doc-0g-7g-docs.googleusercontent.com (doc-0g-7g-docs.googleusercontent.com)|173.194.215.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15017 (15K) [text/csv]
# Saving to: ‘Datos_semana6_Cancer.csv’
#
# Datos_semana6_Cance 100%[===================>]  14.67K  --.-KB/s    in 0s
#
# 2023-12-07 14:47:30 (48.2 MB/s) - ‘Datos_semana6_Cancer.csv’ saved [15017/15017]
#    Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                5                        1                         1
# 1                5                        4                         4
# 2                3                        1                         1
# 3                6                        8                         8
# 4                4                        1                         1
#
#    Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# 0                  1                            2            1
# 1                  5                            7           10
# 2                  1                            2            2
# 3                  1                            3            4
# 4                  3                            2            1
#
#    Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0                3                1        1      2
# 1                3                2        1      2
# 2                3                1        1      2
# 3                3                7        1      2
# 4                3                1        1      2

# %% [markdown]
# Validación de datos nulos

# %%
df.isna()
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0              False                    False                     False
# 1              False                    False                     False
# 2              False                    False                     False
# 3              False                    False                     False
# 4              False                    False                     False
# ..               ...                      ...                       ...
# 678            False                    False                     False
# 679            False                    False                     False
# 680            False                    False                     False
# 681            False                    False                     False
# 682            False                    False                     False
#
#      Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# 0                False                        False        False
# 1                False                        False        False
# 2                False                        False        False
# 3                False                        False        False
# 4                False                        False        False
# ..                 ...                          ...          ...
# 678              False                        False        False
# 679              False                        False        False
# 680              False                        False        False
# 681              False                        False        False
# 682              False                        False        False
#
#      Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0              False            False    False  False
# 1              False            False    False  False
# 2              False            False    False  False
# 3              False            False    False  False
# 4              False            False    False  False
# ..               ...              ...      ...    ...
# 678            False            False    False  False
# 679            False            False    False  False
# 680            False            False    False  False
# 681            False            False    False  False
# 682            False            False    False  False
#
# [683 rows x 10 columns]

# %%
df=df.dropna()
df
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                  5                        1                         1
# 1                  5                        4                         4
# 2                  3                        1                         1
# 3                  6                        8                         8
# 4                  4                        1                         1
# ..               ...                      ...                       ...
# 678                3                        1                         1
# 679                2                        1                         1
# 680                5                       10                        10
# 681                4                        8                         6
# 682                4                        8                         8
#
#      Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# 0                    1                            2            1
# 1                    5                            7           10
# 2                    1                            2            2
# 3                    1                            3            4
# 4                    3                            2            1
# ..                 ...                          ...          ...
# 678                  1                            3            2
# 679                  1                            2            1
# 680                  3                            7            3
# 681                  4                            3            4
# 682                  5                            4            5
#
#      Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0                  3                1        1      2
# 1                  3                2        1      2
# 2                  3                1        1      2
# 3                  3                7        1      2
# 4                  3                1        1      2
# ..               ...              ...      ...    ...
# 678                1                1        1      2
# 679                1                1        1      2
# 680                8               10        2      4
# 681               10                6        1      4
# 682               10                4        1      4
#
# [683 rows x 10 columns]

# %% [markdown]
# Función describe para conocer variables estadísticas

# %%
df.describe()
# Out:
#        Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# count       683.000000               683.000000                683.000000
# mean          4.442167                 3.150805                  3.215227
# std           2.820761                 3.065145                  2.988581
# min           1.000000                 1.000000                  1.000000
# 25%           2.000000                 1.000000                  1.000000
# 50%           4.000000                 1.000000                  1.000000
# 75%           6.000000                 5.000000                  5.000000
# max          10.000000                10.000000                 10.000000
#
#        Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# count         683.000000                   683.000000   683.000000
# mean            2.830161                     3.234261     3.544656
# std             2.864562                     2.223085     3.643857
# min             1.000000                     1.000000     1.000000
# 25%             1.000000                     2.000000     1.000000
# 50%             1.000000                     2.000000     1.000000
# 75%             4.000000                     4.000000     6.000000
# max            10.000000                    10.000000    10.000000
#
#        Bland Chromatin  Normal Nucleoli     Mitoses       Class
# count       683.000000       683.000000  683.000000  683.000000
# mean          3.445095         2.869693    1.603221    2.699854
# std           2.449697         3.052666    1.732674    0.954592
# min           1.000000         1.000000    1.000000    2.000000
# 25%           2.000000         1.000000    1.000000    2.000000
# 50%           3.000000         1.000000    1.000000    2.000000
# 75%           5.000000         4.000000    1.000000    4.000000
# max          10.000000        10.000000   10.000000    4.000000

# %%
df['Class'].value_counts()
# Out:
# 2    444
# 4    239
# Name: Class, dtype: int64

# %% [markdown]
# Evaluación de la media

# %%
mean_value = np.mean(df)
mean_value
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# Clump Thickness                4.442167
# Uniformity of Cell Size        3.150805
# Uniformity of Cell Shape       3.215227
# Marginal Adhesion              2.830161
# Single Epithelial Cell Size    3.234261
# Bare Nuclei                    3.544656
# Bland Chromatin                3.445095
# Normal Nucleoli                2.869693
# Mitoses                        1.603221
# Class                          2.699854
# dtype: float64

# %% [markdown]
# Evaluación de la mediana

# %%
median_value = np.median(df)
median_value
# Out:
# 2.0

# %% [markdown]
# Evaluación de la varianza

# %%
variance_value = np.var(df)
variance_value
# Out:
# Clump Thickness                 7.945045
# Uniformity of Cell Size         9.381357
# Uniformity of Cell Shape        8.918538
# Marginal Adhesion               8.193702
# Single Epithelial Cell Size     4.934873
# Bare Nuclei                    13.258255
# Bland Chromatin                 5.992227
# Normal Nucleoli                 9.305128
# Mitoses                         2.997764
# Class                           0.909912
# dtype: float64

# %% [markdown]
# Evaluación de la correlación

# %%
correlation_coefficient = np.corrcoef(df)
correlation_coefficient
# Out:
# array([[ 1.        ,  0.01897405,  0.86109699, ..., -0.06878018,
#          0.09805807,  0.05140577],
#        [ 0.01897405,  1.        ,  0.24780048, ..., -0.17748521,
#         -0.11287387,  0.09668409],
#        [ 0.86109699,  0.24780048,  1.        , ..., -0.14383556,
#          0.20908335,  0.20037978],
#        ...,
#        [-0.06878018, -0.17748521, -0.14383556, ...,  1.        ,
#          0.71491187,  0.62847037],
#        [ 0.09805807, -0.11287387,  0.20908335, ...,  0.71491187,
#          1.        ,  0.91741662],
#        [ 0.05140577,  0.09668409,  0.20037978, ...,  0.62847037,
#          0.91741662,  1.        ]])

# %% [markdown]
# Evaluación de la desviación estandar

# %%
std_deviation = np.std(df)
std_deviation
# Out:
# Clump Thickness                2.818696
# Uniformity of Cell Size        3.062900
# Uniformity of Cell Shape       2.986392
# Marginal Adhesion              2.862464
# Single Epithelial Cell Size    2.221457
# Bare Nuclei                    3.641189
# Bland Chromatin                2.447903
# Normal Nucleoli                3.050431
# Mitoses                        1.731405
# Class                          0.953893
# dtype: float64
